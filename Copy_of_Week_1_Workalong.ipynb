# %% [markdown]
# <a href="https://colab.research.google.com/github/scarytech/advanced-python-course-things/blob/main/Copy_of_Week_1_Workalong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Week 1 - Structured Data Retrieval
#
# (Be sure to save this to Drive before starting)
#
# We are going to spend the bulk of our time this week retrieving API data into a type of Python variable called JSON that has some structure to it.

# %% [markdown]
# ## A brief recap
#
# There is a chance you haven't touched Python since last class. Before proceeding it might be a good idea to take a look at your notebooks from last time and the course material on the Library Juice Academy Course site.
#
# Take a look at the next code cell and try to guess what it will print before you run it to exercise your Python skills a bit.

# %%
# average temp for the month in degrees C
# in a dictionary variable

yearly_weather = {
    "January": -10,
    "February": -15,
    "March": 5,
    "April": 10,
    "May": 15,
    "June": 20,
    "July": 30,
    "August": 35,
    "September": 30,
    "October": 10,
    "November": 5,
    "December": 0
}


#some loops and conditionals
print("Below 0 months")
for month in yearly_weather:
  if yearly_weather[month] < 0:
    print(month)

print("Above 0 months")
for month in yearly_weather:
  if yearly_weather[month] >= 0:
    print(month)

print("---")

# making our code a bit interactive by asking what cutoff temp to use
cutoff = input("What tempurature do you want to divide on? ")

print("---")

print("Above and equal to "+ cutoff + " months")
for month in yearly_weather:
  if yearly_weather[month] > int(cutoff):
    print(month)

print("Below "+ cutoff + " months")
for month in yearly_weather:
  if yearly_weather[month] < int(cutoff):
    print(month)
# Out:
# Below 0 months
# January
# February
# Above 0 months
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December
# ---
# What tempurature do you want to divide on? 8
# ---
# Above and equal to 8 months
# April
# May
# June
# July
# August
# September
# October
# Below 8 months
# January
# February
# March
# November
# December

# %% [markdown]
# ## But First, indexing
#
# One fundamental skill we should spend a bit of time working on is indexing inside of a data structure. This is a pretty old school thing but it is worth learning none the same. We'll see that it comes in handy when selecting subsets of lists. In Python this is called using the `slice` operator.
#
# This is useful for us because we will be loading up big `lists` of data and sometimes we only want to look at a bit of that data.

# %%
countries = ["Brazil","Spain","Italy","United Kingdom","Germany","France"]

#Prints the first item
print(countries[0])

#Prints the last item
#Using a negative number will start the indexing at the end
print(countries[-1])

#Prints a third and fourth item
#Using a : will tell Python you want multiple items
#this is called the slice operator
print(countries[2:4])

#Prints the last two items
#Combination of negative values and the colon (slice)
print(countries[-2:])
# Out:
# Brazil
# France
# ['Italy', 'United Kingdom']
# ['Germany', 'France']

# %% [markdown]
# **Q1** Print the 3rd item in the `countries` list

# %%
#Q1
print(countries[2])
# Out:
# Italy

# %% [markdown]
# **Q2** Print the dogs in the following list, using the slice operator.

# %%
#Q2

animals = ["Garfield","Odie","Clifford","Nemo"]
print(animals[0:4])
# Out:
# ['Garfield', 'Odie', 'Clifford', 'Nemo']

# %% [markdown]
# **Q3** Print your favorite dessert to the screen. Assuming your favourite is in this list!

# %%
#Q3
desserts = ["Pie","Cake","Ice Cream","Sherbert"]
print(desserts[1])
# Out:
# Cake

# %% [markdown]
# ##Grabbing information
#
# We can get Python to retrieve information from the web by using the [requests]() library that will grab a web-page. Once we have that we can do interesting things with the contents as well as the metadata of the request.
#
# We'll be using a [CollectionBuilder](https://collectionbuilder.github.io/) exhibit for this week's material. It is the one I use for the [AI in Libraries, for Skeptics](https://libraryjuiceacademy.com/shop/course/331-ai-and-libraries-for-skeptics/) class.
#
# Run the next set of cells to see this in action.

# %%
#Our New Library!
import requests


#Grab the HTML of the CollectionBuilder page we will look at later
#It will be put in a variable called response
response = requests.get("https://elibtronic.github.io/AIL_Database/")

print("Page has been retrieved!")
# Out:
# Page has been retrieved!

# %%
#Prints the response code from the request
#200 is successful request
#List of codes: https://en.wikipedia.org/wiki/List_of_HTTP_status_codes
print(response.status_code)
# Out:
# 200

# %%
#Prints the HTML Headers
#List of headers: https://en.wikipedia.org/wiki/List_of_HTTP_header_fields
print(response.headers)
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '7009', 'Server': 'GitHub.com', 'Content-Type': 'text/html; charset=utf-8', 'Last-Modified': 'Tue, 19 Aug 2025 19:40:35 GMT', 'Access-Control-Allow-Origin': '*', 'ETag': 'W/"68a4d333-672e"', 'expires': 'Mon, 01 Sep 2025 05:32:28 GMT', 'Cache-Control': 'max-age=600', 'Content-Encoding': 'gzip', 'x-proxy-cache': 'MISS', 'X-GitHub-Request-Id': 'C644:11BFBE:7A98131:7B49A2B:68B52D92', 'Accept-Ranges': 'bytes', 'Age': '0', 'Date': 'Mon, 01 Sep 2025 05:22:28 GMT', 'Via': '1.1 varnish', 'X-Served-By': 'cache-ams21034-AMS', 'X-Cache': 'MISS', 'X-Cache-Hits': '0', 'X-Timer': 'S1756704148.379973,VS0,VE138', 'Vary': 'Accept-Encoding', 'X-Fastly-Request-ID': '7b207d3112c1cce376ddb1548078dd05c0c04e19'}

# %%
#Print the content of the webpage
#This will spit out a bunch of unformated HTML text so be ready
print(response.text)
# Out:
# <!doctype html>
# <html lang="en" class="h-100">
#   <head prefix="og: http://ogp.me/ns#">
#     <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# <title>Home | AI.LD</title>
# <link rel="shortcut icon" type="image/x-icon" href="/AIL_Database/favicon.ico">
# <!--
#
#   _____     ____        __  _           ___       _ __   __
#  / ___/__  / / /__ ____/ /_(_)__  ___  / _ )__ __(_) /__/ /__ ____
# / /__/ _ \/ / / -_) __/ __/ / _ \/ _ \/ _  / // / / / _  / -_) __/
# \___/\___/_/_/\__/\__/\__/_/\___/_//_/____/\_,_/_/_/\_,_/\__/_/
#
#     built with CollectionBuilder-CSV
#     https://github.com/CollectionBuilder/collectionbuilder-csv
# -->
# <meta name="generator" content="collectionbuilder-csv" />
# <meta http-equiv="Content-Language" content="en-us" >
#
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootswatch@5.1.3/dist/materia/bootstrap.min.css" type="text/css">
# <link rel="stylesheet" href="/AIL_Database/assets/css/cb.css" type="text/css">
#
#
# <meta name="description" content="Database of resources generated by the LJA Course &lt;a href=&#39;https://libraryjuiceacademy.com/shop/course/331-ai-and-libraries-for-skeptics/&#39;&gt;AI and Libraries, For Skeptics&lt;/a&gt;">
# <meta name="author" content="elibtronic; " >
# <!-- DC meta -->
# <link rel="schema.DCTERMS" href="http://purl.org/dc/terms/" />
# <meta name="DCTERMS.title" content="Home, AI.LD" xml:lang="en" />
# <meta name="DCTERMS.creator" content="elibtronic" xml:lang="en" />
#
# <meta name="DCTERMS.date" content="2025" xml:lang="en" />
# <meta name="DCTERMS.description" content="Database of resources generated by the LJA Course &lt;a href=&#39;https://libraryjuiceacademy.com/shop/course/331-ai-and-libraries-for-skeptics/&#39;&gt;AI and Libraries, For Skeptics&lt;/a&gt;" xml:lang="en" />
#
# <!-- Open Graph meta -->
# <meta property="og:title" content="Home, AI.LD" />
# <meta property="og:description" content="Database of resources generated by the LJA Course &lt;a href=&#39;https://libraryjuiceacademy.com/shop/course/331-ai-and-libraries-for-skeptics/&#39;&gt;AI and Libraries, For Skeptics&lt;/a&gt;" />
# <meta property="og:site_name" content="AI.LD" />
# <meta property="og:type" content="website" />
# <meta property="og:image" content="/AIL_Database/assets/img/collectionbuilder-logo.png" />
# <meta property="og:image:alt" content="AI.LD" />
# <meta property="og:url" content="https://elibtronic.github.io/AIL_Database/" />
# <meta property="og:locale" content="en_US" />
# <!-- schema.org JSON-LD -->
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"WebPage","headline":"Home, AI.LD","publisher": { "@context": "https://schema.org", "@type": "Organization", "name": "", "url": "", "logo": "" },"description":"Database of resources generated by the LJA Course <a href='https://libraryjuiceacademy.com/shop/course/331-ai-and-libraries-for-skeptics/'>AI and Libraries, For Skeptics</a>","image":"/AIL_Database/assets/img/collectionbuilder-logo.png","url":"https://elibtronic.github.io/AIL_Database/"}</script>
# <!-- breadcrumbs schema -->
# <script type="application/ld+json">{"@context": "http://schema.org", "@type": "BreadcrumbList", "itemListElement": [{ "@type": "ListItem", "position": 1, "item": { "@id": "https://elibtronic.github.io/AIL_Database/", "name": "AI.LD" } },{ "@type": "ListItem", "position": 2, "item": { "@id": "https://elibtronic.github.io/AIL_Database/", "name": "Home" } }] }</script>
#
#
# <!-- Analytics -->
#
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-368028066"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'G-368028066', {
#     'anonymize_ip': true
#   });
# </script>
# <!-- Last build date: 2025-08-19 -->
#   </head>
#   <body class="d-flex flex-column h-100">
#     <div id="skip-to-content"><a href="#maincontent">Skip to main content</a></div>
#     <div class="container">
#     <div class="row align-items-center">
#         <div id="title" class="col-12">
#             <h1 class="mt-2"><a class="text-dark" href="/AIL_Database/" >AI.LD</a></h1>
#             <p>AI and Libraries Database</p>
#         </div>
#
#     </div>
# </div>
#     <nav class="navbar navbar-expand-lg navbar-dark bg-dark">
#     <div class="container">
#         <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#page-nav" aria-controls="page-nav" aria-expanded="false" aria-label="Toggle navigation">
#             <span class="navbar-toggler-icon"></span>
#         </button>
#
#
#
#         <div class="collapse navbar-collapse" id="page-nav">
#             <ul class="navbar-nav me-auto">
#
#                 <li class="nav-item">
#                     <a class="nav-link active" href="/AIL_Database/">Home</a>
#                 </li>
#
#                 <li class="nav-item">
#                     <a class="nav-link" href="/AIL_Database/browse.html">Browse</a>
#                 </li>
#
#                 <li class="nav-item">
#                     <a class="nav-link" href="/AIL_Database/subjects.html">Subjects</a>
#                 </li>
#
#                 <li class="nav-item">
#                     <a class="nav-link" href="/AIL_Database/timeline.html">Timeline</a>
#                 </li>
#
#                 <li class="nav-item">
#                     <a class="nav-link" href="/AIL_Database/data.html">Data</a>
#                 </li>
#
#                 <li class="nav-item">
#                     <a class="nav-link" href="/AIL_Database/about.html">About</a>
#                 </li></ul>
#
#             <script>
#     function site_search() {
#         var query = document.getElementById("site-search").value;
#         window.open("/AIL_Database/search/index.html?q=" + encodeURIComponent(query), "_self" );
#     }
# </script>
# <form class="form-inline my-2 my-lg-0" role="search" id="search" onsubmit="site_search(); return false;">
#     <div class="input-group">
#         <input id="site-search" class="form-control " type="text" placeholder="Search" aria-label="Search box">
#         <button class="btn btn-light" type="submit">
#             <span id="search-icon"><svg viewBox="0 0 1024 974" height="16px" width="20px"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z"/></svg></span>
#             <span class="visually-hidden">Search</span>
#         </button>
#     </div>
# </form>
#
#         </div>
#     </div>
# </nav>
#
#     <main id="maincontent" role="main" class="flex-shrink-0">
#       <div class="container my-4">
#   <div class="row">
#
#   <div class="col-md-8">
#
#     <div class="card mb-3">
#   <div class="card-body">
#     <h2 class="card-title h5">Description</h2>
#     <p class="card-text">Database of resources generated by the LJA Course <a href='https://libraryjuiceacademy.com/shop/course/331-ai-and-libraries-for-skeptics/'>AI and Libraries, For Skeptics</a></p>
#     <a class="btn btn-primary" href="/AIL_Database/about.html" role="button">Learn More &raquo;</a>
#   </div>
# </div>
#
#     <style>
#     #imageCarousel .carousel-item { height: 300px; }
# </style>
# <div class="card mb-3">
#
#     <div class="card-body">
#         <h2 class="card-title h5">Sample Items</h2>
#
#         <div id="imageCarousel" class="carousel slide bg-dark rounded mb-3" data-bs-ride="carousel">
#             <div id="carouselIndicators" class="carousel-indicators">
#
#             </div>
#             <div id="carouselInner" class="carousel-inner">
#
#             </div>
#             <button class="carousel-control-prev" type="button" data-bs-target="#imageCarousel" data-bs-slide="prev">
#                 <span class="carousel-control-prev-icon" aria-hidden="true"></span>
#                 <span class="visually-hidden">Previous</span>
#             </button>
#             <button class="carousel-control-next" type="button" data-bs-target="#imageCarousel" data-bs-slide="next">
#                 <span class="carousel-control-next-icon" aria-hidden="true"></span>
#                 <span class="visually-hidden">Next</span>
#             </button>
#         </div>
#
#     </div>
# </div><script>
#     /* add item data */
#     // title,objectid,image_thumb/small
#     var carouselItems = [ [ "On the Dangers of Stochastic Parrots: Can Language Models Be Too Big? 🦜", "ail_001", "/AIL_Database/objects/ail_001.png", "", "screen capture of resource" ], [ "What do we mean by equitable and accountable AI?", "ail_002", "/AIL_Database/objects/ail_002.png", "", "screen capture of resource" ], [ "Can we build AI without losing control over it?", "ail_003", "/AIL_Database/objects/ail_003.png", "", "screen capture of resource" ], [ "Learn to Take on the Ceiling", "ail_004", "/AIL_Database/objects/ail_004.png", "", "screen capture of resource" ], [ "We need a manifesto for Responsible AI", "ail_005", "/AIL_Database/objects/ail_005.png", "", "screen capture of resource" ], [ "ChatGPT: Implications for academic libraries", "ail_006", "/AIL_Database/objects/ail_006.png", "", "screen capture of resource" ], [ "Why automated content moderation won&#39;t save us", "ail_007", "/AIL_Database/objects/ail_007.png", "", "screen capture of resource" ], [ "An AI toolkit for libraries", "ail_008", "/AIL_Database/objects/ail_008.png", "", "screen capture of resource" ], [ "The Democratization of Artificial Intelligence: One Library&#39;s approach", "ail_009", "/AIL_Database/objects/ail_009.png", "", "screen capture of resource" ], [ "How an Iowa School District Used ChatGPT to Ban Books", "ail_010", "/AIL_Database/objects/ail_010.png", "", "screen capture of resource" ], [ "Generative AI for the Library and Information Professionals", "ail_011", "/AIL_Database/objects/ail_011.png", "", "screen capture of resource" ], [ "Using chatgpt to engage in library instruction? Challenges and opportunities", "ail_012", "/AIL_Database/objects/ail_012.png", "", "screen capture of resource" ], [ "OpenAI confirms that AI writing detectors don&#39;t work", "ail_013", "/AIL_Database/objects/ail_013.png", "", "screen capture of resource" ], [ "The Rise of AI: Implications and Applications of Artificial Intelligence in Academic Libraries by Sandy Hervieux and Amanda Wheatley", "ail_014", "/AIL_Database/objects/ail_014.png", "", "screen capture of resource" ], [ "Algorithmic Literacy and the Role for Libraries", "ail_015", "/AIL_Database/objects/ail_015.png", "", "screen capture of resource" ], [ "How artificial intelligence might change academic library work: Applying the competencies literature and the theory of the professions", "ail_016", "/AIL_Database/objects/ail_017.png", "", "screen capture of resource" ], [ "AI in Libraries: Seven Principles", "ail_017", "/AIL_Database/objects/ail_018.png", "", "screen capture of resource" ], [ "Introducing the LC Labs Artificial Intelligence Planninng  Framework", "ail_018", "/AIL_Database/objects/ail_018.png", "", "screen capture of resource" ], [ "Evolving AI Strategies in Libraries: Insights from Two Polls of ARL Member Representatives over Nine Months", "ail_019", "/AIL_Database/objects/ail_019.png", "", "screen capture of resource" ], [ "Intro to AI for GLAM", "ail_020", "/AIL_Database/objects/ail_020.png", "", "screen capture of resource" ], [ "Researchers devise approach to reduce biases in computer vision data sets", "ail_021", "/AIL_Database/objects/ail_021.png", "", "screen capture of resource" ], [ "GitHub&#39;s automatic coding tool rests on untested legal ground", "ail_022", "/AIL_Database/objects/ail_022.png", "", "screen capture of resource" ], [ "In Hollywood writers&#39; battle against AI, humans win (for now)", "ail_023", "/AIL_Database/objects/ail_023.png", "", "screen capture of resource" ], [ "Introducing our AI Metadata Generator", "ail_024", "/AIL_Database/objects/ail_024.png", "", "screen capture of resource" ], [ "Exclusive: OpenAI Used Kenyan Workers on Less Than $2 Per Hour to Make ChatGPT Less Toxic", "ail_025", "/AIL_Database/objects/ail_025.png", "", "screen capture of resource" ], [ "What is Retrival-Augmented Generation (RAG?)", "ail_026", "/AIL_Database/objects/ail_026.png", "", "screen capture of resource" ], [ "Stability AI reportedly ran out of cash to pay ...
#     /* shuffle items */
#     carouselItems.sort(function() { return 0.5 - Math.random() });
#
#     /* add items to carousel */
#     var carousel = document.getElementById("carouselInner");
#     var carouselIndicators = document.getElementById("carouselIndicators");
#     var slides = "";
#     var indicators = "";
#     var i, itemImg, itemLink;
#     for (i=0; i < 9; i++) {
#         // calculate item image location
#         itemImg = carouselItems[i][2];
#         // calculate item link
#         if (carouselItems[i][3]){
#             itemLink = '/AIL_Database/items/' + carouselItems[i][3] + '.html#' + carouselItems[i][1];}
#         else {
#             itemLink = '/AIL_Database/items/' + carouselItems[i][1] + '.html';
#         }
#         // create indicator
#         indicator = `<button type="button" data-bs-target="#imageCarousel" data-bs-slide-to="${i.toString()}" ${ i == 0 ? 'class="active" aria-current="true" ' : '' }aria-label="Slide ${i.toString()}"></button>`;
#         // create slide
#         slide = `<div class="carousel-item py-2${ i == 0 ? ' active' : '' }">
#             <img class="d-block h-100 mx-auto lazyload" alt="${carouselItems[i][4]}" data-src="${itemImg}">
#             <div class="carousel-caption">
#                 <h3 class="carousel-item-title text-white py-2 h6">${carouselItems[i][0]}</h3>
#                 <a target="_blank" href="${itemLink}" class="btn btn-sm btn-primary">View Item</a>
#             </div></div>`;
#         slides += slide;
#         indicators += indicator;
#     }
#     // add indicators to page
#     carouselIndicators.innerHTML = indicators;
#     // add slides to the page
#     carousel.innerHTML = slides;
# </script>
#
#
#   </div>
#   <div class="col-md-4">
#
#     <div class="card mb-3">
#   <div class="card-body">
#     <h2 class="card-title h5">Time Span</h2>
#     <p class="card-text h5">2019 to 2025
#       <br><a href="/AIL_Database/timeline.html" class="btn btn-sm btn-outline-secondary mt-2">View Timeline</a>
#     </p>
#   </div>
# </div>
#
#
#     <div class="card mb-3">
#
#     <div class="card-body">
#         <h2 class="card-title h5">Top Subjects</h2>
#         <p class="card-text">
#
#             <a class="btn btn-sm btn-primary m-1" href="/AIL_Database/browse.html#generative-ai">generative-ai</a>
#             <a class="btn btn-sm btn-primary m-1" href="/AIL_Database/browse.html#ethics">ethics</a>
#             <a class="btn btn-sm btn-primary m-1" href="/AIL_Database/browse.html#news">news</a>
#             <a class="btn btn-sm btn-primary m-1" href="/AIL_Database/browse.html#blog">blog</a>
#             <a class="btn btn-sm btn-primary m-1" href="/AIL_Database/browse.html#library">library</a>
#         </p>
#     </div>
# </div>
#
#
#     <div class="card mb-3">
#
#     <div class="card-body">
#         <h2 class="card-title h5">Locations</h2>
#         <p class="card-text">
#
#             <a class="btn btn-sm btn-outline-secondary m-1" href="/AIL_Database/browse.html"></a>
#         </p>
#     </div>
# </div>
#
#
#     <div class="card mb-3" >
#   <div class="card-body">
#     <h2 class="card-title h5">Objects</h2>
#     <p class="card-text">
#       <a class="btn btn-sm btn-outline-secondary mt-2" href="/AIL_Database/data.html">View table</a>
#     </p>
#   </div>
# </div>
#
#   </div>
#   <div class="col-md-12">
#
#     <div class="card mb-3">
#     <div class="card-body">
#         <h2 class="card-title h5">Collection as Data <small>(click to download)</small></h2>
#         <p class="card-text text-center">
#             <a class="btn btn-sm btn-secondary m-2" href="/AIL_Database/assets/data/metadata.csv" target="_blank">Metadata CSV</a>
#             <a class="btn btn-sm btn-secondary m-2" href="/AIL_Database/assets/data/metadata.json" target="_blank">Metadata JSON</a>
#
#             <a class="btn btn-sm btn-secondary m-2" href="/AIL_Database/assets/data/subjects.json" target="_blank">Subjects JSON</a>
#             <a class="btn btn-sm btn-secondary m-2" href="/AIL_Database/assets/data/subjects.csv" target="_blank">Subjects CSV</a>
#
#
#
#
#             <a class="btn btn-sm btn-secondary m-2" href="/AIL_Database/assets/data/timelinejs.json" target="_blank">Timeline JSON</a>
#
#
#             <a class="btn btn-sm btn-secondary m-2" href="/AIL_Database/assets/data/facets.json" target="_blank">Facets JSON</a>
#
#             <a class="btn btn-sm btn-secondary m-2" href="https://github.com/CollectionBuilder/collectionbuilder-csv" rel="noopener" target="_blank">Source Code</a>
#         </p>
#     </div>
# </div>
#
#   </div>
#
# </div>
# </div>
#     </main>
#     <footer class="bg-dark pt-4 mt-auto container-fluid">
#
#     <div class="row border-bottom border-white pb-4 mb-2">
#
#         <div class="col-md-7 px-4 mt-3">
#
#             <h2 class="h4"><a href="/AIL_Database/" class="text-white">AI.LD</a></h2>
#             <p class="text-white"><small>Database of resources generated by the LJA Course <a href='https://libraryjuiceacademy.com/shop/course/331-ai-and-libraries-for-skeptics/'>AI and Libraries, For Skeptics</a></small></p>
#             <nav>
#                 <ul id="footer-nav" class="nav nav-pills ">
#                     <li class="nav-item">
#
#                         <a class="nav-link text-light active" href="/AIL_Database/">Home</a>
#                     </li>
#                     <li class="nav-item">
#
#                         <a class="nav-link text-light" href="/AIL_Database/browse.html">Browse</a>
#                     </li>
#                     <li class="nav-item">
#
#                         <a class="nav-link text-light" href="/AIL_Database/subjects.html">Subjects</a>
#                     </li>
#                     <li class="nav-item">
#
#                         <a class="nav-link text-light" href="/AIL_Database/timeline.html">Timeline</a>
#                     </li>
#                     <li class="nav-item">
#
#                         <a class="nav-link text-light" href="/AIL_Database/data.html">Data</a>
#                     </li>
#                     <li class="nav-item">
#
#                         <a class="nav-link text-light" href="/AIL_Database/about.html">About</a>
#                     </li></ul>
#             </nav>
#
#         </div>
#
#         <div class="col-md-5 mt-3 text-center">
#
#
#             <p class="text-white text-md-end" id="footer-credits">
#                 <small><em>built with</em>
#                     <a href="https://collectionbuilder.github.io/" target="_blank" rel="noopener" title="CollectionBuilder">
#                         <img src="/AIL_Database/assets/img/collectionbuilder-logo.png" class="img-fluid" alt="CollectionBuilder" >
#                     </a>
#                 </small>
#             </p>
#
#         </div>
#
#     </div>
#
#     <div class="col-md-12 text-center pt-3 pb-1">
#         <p class="text-white">Last updated 2025</p>
#     </div>
#
# </footer>
#     <!-- Bootstrap bundle JS -->
# <script src="/AIL_Database/assets/lib/bootstrap.bundle.min.js"></script>
# <!-- load other js -->
# <script src="/AIL_Database/assets/lib/lazysizes.min.js" async></script>
#
#
#     <script>
#     // When the user scrolls down from the top of the document, show the button
#     window.onscroll = function () {
#         if (document.body.scrollTop > 500 || document.documentElement.scrollTop > 500) {
#             document.getElementById("scroll-to-top").style.display = "block";
#         } else {
#             document.getElementById("scroll-to-top").style.display = "none";
#         }
#     }
#     // scroll to top function
#     function scrollToTop() {
#         window.scroll({
#             top: 0,
#             left: 0,
#             behavior: 'smooth'
#         });
#     }
# </script>
# <button id="scroll-to-top" type="button" class="btn btn-link" onclick="scrollToTop();" title="Back to Top" aria-label="Back to Top">
#     <svg class="bi icon-sprite" role="img" aria-label="Up Arrow">
#         <use xlink:href="/AIL_Database/assets/lib/cb-icons.svg#icon-back-to-top"/>
#     </svg>
# </button>
#   </body>
# </html>

# %% [markdown]
# ##Total information from a CollectionBuilder site
#
# Now that we have learned to grab random webpages into Python we are going to move towards retrieving structured information. Instead of a random webpage we are going to grab information from an API.
#
# Further we are going to be working with structured data called JSON.

# %%
#Our library to work with JSON
import json

#Our old friend pandas
import pandas as pd

# %% [markdown]
# ## Collection Builder
#
# CollectionBuilder is a great platform for turning a spreadsheet of infomration into a full fledged website. I use it for lots of different things, for example I create a [database](https://elibtronic.github.io/AIL_Database/) of readings for my other Library Juice class. Most importantly for us however is that CollectionBuilder also has an _API_ interface it creates for ever site. So you can look at the site dressed up as HTML, but also as data in a format called JSON.
#
# CollectionBuilder sites by default present links to several different JSON components of the site. For the form below I've added a link to the _Metadata_ JSON url for my site.

# %%
# @title URL of JSON File for complete CollectionBuilder Metadata {"run":"auto","display-mode":"form"}

json_cb_url = "https://elibtronic.github.io/AIL_Database/assets/data/metadata.json" # @param {"type":"string","placeholder":"https://elibtronic.github.io/AIL_Database/assets/data/metadata.json"}
# @markdown (Click _Show Code_ to see everything that is going on here)

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
objects_cb_data = total_cb_data['objects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# ###Printing all items in a JSON object
#
# Run the next couple of cells to see all of the data used by the site in a nice pleasing output. You can open up the collection builders [data page](https://elibtronic.github.io/AIL_Database/data.html) in another tab to see the data represented in a webpage instead of plain text.

# %%
#Will just print out the 'objects' in the JSON object, probably more useful
#Don't worry if this looks like mush, we'll focus in on some exact data
#in the upcoming sections
print(json.dumps(objects_cb_data,indent=2))
# Out:
# [
#   {
#     "title": "On the Dangers of Stochastic Parrots: Can Language Models Be Too Big? \ud83e\udd9c",
#     "creator": "Bender, M. Emily; Gebru, Timnit; McMillian-Major; Shmitchell, Shmargaret",
#     "date": "2021-03-01",
#     "description": "The past 3 years of work in NLP have been characterized by the development and deployment of ever larger language models, especially for English. BERT, its variants, GPT-2/3, and others, most recently Switch-C, have pushed the boundaries of the possible both through architectural innovations and through sheer size. Using these pretrained models and the methodology of fine-tuning them for specific tasks, researchers have extended the state of the art on a wide array of tasks as measured by leaderboards on specific benchmarks for English. In this paper, we take a step back and ask: How big is too big? What are the possible risks associated with this technology and what paths are available for mitigating those risks? We provide recommendations including weighing the environmental and financial costs first, investing resources into curating and carefully documenting datasets rather than ingesting everything on the web, carrying out pre-development exercises evaluating how the planned approach fits into research and development goals and supports stakeholder values, and encouraging research directions beyond ever larger language models.",
#     "subject": "generative-AI;paper",
#     "language": "eng",
#     "URL": "https://doi.org/10.1145/3442188.3445922",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_001.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_001.html"
#   },
#   {
#     "title": "What do we mean by equitable and accountable AI?",
#     "creator": "Algorithm Justice League",
#     "date": "2024-02-14",
#     "description": "Provides definition and description of equitable and accountable AI",
#     "subject": "week-1;ethics;statement",
#     "language": "eng",
#     "URL": "https://www.ajl.org/learn-more",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_002.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_002.html"
#   },
#   {
#     "title": "Can we build AI without losing control over it?",
#     "creator": "Harris, Sam",
#     "date": "2024-02-14",
#     "description": "Harris is a neuroscientist and philosopher,  this is the video of a TED talk he gave on the topic",
#     "subject": "week-1;ethics;agi;video",
#     "language": "eng",
#     "URL": "https://www.youtube.com/watch?v=8nt3edWLgIg",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_003.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_003.html"
#   },
#   {
#     "title": "Learn to Take on the Ceiling",
#     "creator": "Reben, A",
#     "date": "2021-01-01",
#     "description": "Reading found on page 105 - 114",
#     "subject": "week-1;generative-AI;critique;chapter",
#     "language": "eng",
#     "URL": "http://archive.org/details/fake-ai",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_004.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_004.html"
#   },
#   {
#     "title": "We need a manifesto for Responsible AI",
#     "creator": "CILIP: the library and information association",
#     "date": "2023-09-07",
#     "description": "Speech given by the CEO of Chartered Institute of Library and Information Professionals (CILIP) based in the UK.",
#     "subject": "week-1;statement;library",
#     "language": "eng",
#     "URL": "https://www.cilip.org.uk/news/650937/We-need-a-manifesto-for-Responsible-AI.htm",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_005.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_005.html"
#   },
#   {
#     "title": "ChatGPT: Implications for academic libraries",
#     "creator": "Cox, C.; Tzoc, E",
#     "date": "2023-03-01",
#     "description": "A collection of possible outcomes from ChatGPT for Academic Libraries",
#     "subject": "week-2;paper;library",
#     "language": "eng",
#     "URL": "http://doi.org/10.5860/crln.84.3.99",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_006.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_006.html"
#   },
#   {
#     "title": "Why automated content moderation won't save us",
#     "creator": "Strait,A",
#     "date": "2021-01-01",
#     "description": "Reading found on page 147 - 159",
#     "subject": "week-2;ethics;critique;chapter",
#     "language": "eng",
#     "URL": "http://archive.org/details/fake-ai",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_007.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_007.html"
#   },
#   {
#     "title": "An AI toolkit for libraries",
#     "creator": "Upshall, M.",
#     "date": "2022-01-01",
#     "description": "Now that artificial intelligence (AI) tools are being widely used across academic publishing, how can we make informed assessments of these utilities? There is a need for a set of skills for evaluating new tools and measuring existing ones, which should enable anyone commissioning or managing AI utilities to understand what questions to ask, what parameters to measure and possible pitfalls to avoid when introducing a new utility. The skills required are not technical. Potential problems include bias in the corpus, a poor training set or poor use of metrics for evaluation. This article gives a quick overview of some of areas where AI tools are being used and how they work. It then provides a checklist for assessment. The goal is not to discredit AI, but to make effective use of it.",
#     "subject": "week-2;library;resource",
#     "language": "eng",
#     "URL": "https://doi.org/10.1629/uksg.592",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_008.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_008.html"
#   },
#   {
#     "title": "The Democratization of Artificial Intelligence: One Library's approach",
#     "creator": "Finley, T. K.",
#     "date": "2019-01-01",
#     "description": "This article argues that the current technological revolution that is happening in Artificial Intelligence is not just about its prevalence in daily life, but the real revolution is about the emergence of AI tools that may help to democratize its use. Lowering the barrier to a technology that is perceived more as science fiction than accessible for mass utilization. A Public Library shares its approach in leveraging available tools to enable AI education for all.",
#     "subject": "week-2;paper;library",
#     "language": "eng",
#     "URL": "https://doi.org/10.6017/ital.v38i1.10974",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_009.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_009.html"
#   },
#   {
#     "title": "How an Iowa School District Used ChatGPT to Ban Books",
#     "creator": "Watercutter, A.",
#     "date": "2020-01-01",
#     "description": "Recalls the story of how ChatGPT was used to aid in a weeding exercise.",
#     "subject": "week-3;ethics;news",
#     "language": "eng",
#     "URL": "https://www.wired.com/story/chatgpt-ban-books-iowa-schools-sf-496/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_010.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_010.html"
#   },
#   {
#     "title": "Generative AI for the Library and Information Professionals",
#     "creator": "IFLA",
#     "date": "2024-04-01",
#     "description": "List of defitions and further links regarding generative AI from International Federation of Library Associations and Instutions (IFLA)",
#     "subject": "week-3;library;statement;generative-AI",
#     "language": "eng",
#     "URL": "https://www.ifla.org/generative-ai/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_011.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_011.html"
#   },
#   {
#     "title": "Using chatgpt to engage in library instruction? Challenges and opportunities",
#     "date": "2023-02-23",
#     "description": "Video presentation on the use of ChatGPT in Library instruction",
#     "subject": "video;library;resource",
#     "language": "eng",
#     "URL": "https://www.youtube.com/watch?v=ddkbWPp9ezM",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_012.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_012.html"
#   },
#   {
#     "title": "OpenAI confirms that AI writing detectors don't work",
#     "creator": "Edward, B.",
#     "date": "2023-01-01",
#     "description": "Describes communications from OpenAI describing the limitations of AI detectors",
#     "subject": "week-4;generative-AI;news",
#     "language": "eng",
#     "URL": "https://arstechnica.com/information-technology/2023/09/openai-admits-that-ai-writing-detectors-dont-work/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_013.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_013.html"
#   },
#   {
#     "title": "The Rise of AI: Implications and Applications of Artificial Intelligence in Academic Libraries by Sandy Hervieux and Amanda Wheatley",
#     "creator": "Bartlomeij, A. L.",
#     "date": "2023-06-21",
#     "description": "Book review of a Association of College and Research Libraries (ARCL) publication on AI",
#     "subject": "week-4;paper;book-review",
#     "language": "eng",
#     "URL": "https://doi.org/10.33137/cjal-rcbu.v9.41129",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_014.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_014.html"
#   },
#   {
#     "title": "Algorithmic Literacy and the Role for Libraries",
#     "creator": "Ridley, M., & Pawlick-Potts, D.",
#     "date": "2021-06-17",
#     "description": "Artificial intelligence (AI) is powerful, complex, ubiquitous, often opaque, sometimes invisible, and increasingly consequential in our everyday lives. Navigating the effects of AI as well as utilizing it in a responsible way requires a level of awareness, understanding, and skill that is not provided by current digital literacy or information literacy regimes. Algorithmic literacy addresses these gaps. In arguing for a role for libraries in algorithmic literacy, the authors provide a working definition, a pressing need, a pedagogical strategy, and two specific contributions that are unique to libraries.",
#     "subject": "week-3;ethics;paper",
#     "language": "eng",
#     "URL": "https://doi.org/10.6017/ital.v40i2.12963",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_015.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_015.html"
#   },
#   {
#     "title": "How artificial intelligence might change academic library work: Applying the competencies literature and the theory of the professions",
#     "creator": "Cox, A.",
#     "date": "2022-03-07",
#     "description": "The probable impact of artificial intelligence (AI) on work, including professional work, is contested, but it is unlikely to leave them untouched. The purpose of this conceptual paper is to consider the likelihood of the adoption of different approaches to AI in academic libraries. As theoretical lenses to guide the analysis the paper draws on both the library and information science (LIS) literature on librarians' competencies and the notions of jurisdiction and hybrid logics drawn from the sociological theory of the professions. The paper starts by outlining these theories and then reviews the nature of AI and the range of its potential uses in academic libraries. The main focus of the paper is on the application of AI to knowledge discovery. Eleven different potential approaches libraries might adopt to such AI applications are analyzed and their likelihood evaluated. Then it is considered how a range of internal and external factors might influence the adoption of AI. In addition to reflecting on the possible impact of AI on librarianship the paper contributes to understanding how to synthesize the competencies literature with the theory of the profession and presents a new understanding of librarians as hybrid.",
#     "subject": "library;ethics;paper",
#     "language": "eng",
#     "URL": "https://doi.org/10.1002/asi.24635",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_017.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_016.html"
#   },
#   {
#     "title": "AI in Libraries: Seven Principles",
#     "creator": "Wessel, V.; Willem, J.",
#     "date": "2020-05-2020",
#     "description": "Artificial Intelligence (AI) plays an increasingly important role in reading, learning and research, the core activities of the library. The National Library of the Netherlands (KB) appreciates the  reat possibilities that AI offers to help us accomplish our mission to make our users smarter, more reative and more skilled. At the same time we do not close our eyes for unforeseen and unwanted side effects of AI, which may raise ethical questions, perhaps more than other forms of digital transformation. As National Library we feel we have a responsibility in addressing these issues. We have formulated seven principles we feel any AI-application in the context of the Library should comply with. Seven principles that takes the potential and the benefits of AI as starting point, and at the same imes give guidelines to avoid ethical pitfalls.",
#     "subject": "library;resource",
#     "language": "eng",
#     "URL": "https://zenodo.org/doi/10.5281/zenodo.3865343",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_018.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_017.html"
#   },
#   {
#     "title": "Introducing the LC Labs Artificial Intelligence Planninng  Framework",
#     "creator": "Potter, A.",
#     "date": "2023-11-23",
#     "description": "Blog post summarizing the introduction of the LC Labs AI Planning Framework.",
#     "subject": "statement;library;generative-AI",
#     "language": "eng",
#     "URL": "https://blogs.loc.gov/thesignal/2023/11/introducing-the-lc-labs-artificial-intelligence-planning-framework/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_018.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_018.html"
#   },
#   {
#     "title": "Evolving AI Strategies in Libraries: Insights from Two Polls of ARL Member Representatives over Nine Months",
#     "creator": "Leo, L. & Vitale, C. H.",
#     "date": "2024-03-01",
#     "description": "The onset of new, more accessible, artificial intelligence (AI) technologies marks a significant turning point for libraries, ushering in a period rich with both unparalleled opportunities and complex challenges. In this era of swift technological transformation, libraries stand at a critical intersection. To effectively chart this transition, two quick polls were conducted among members of the Association of Research Libraries (ARL).",
#     "subject": "library;poll;policy",
#     "language": "eng",
#     "URL": "https://doi.org/10.29242/report.aipolls2023",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_019.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_019.html"
#   },
#   {
#     "title": "Intro to AI for GLAM",
#     "creator": "The Carpentries",
#     "date": "2024-01-31",
#     "description": "Tutorial focused on Librarian crowd that presents a from scratch introduction to AI.",
#     "subject": "library;resource;generative-AI",
#     "language": "eng",
#     "URL": "https://carpentries-incubator.github.io/machine-learning-librarians-archivists/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_020.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_020.html"
#   },
#   {
#     "title": "Researchers devise approach to reduce biases in computer vision data sets",
#     "creator": "Shariach, M.",
#     "date": "2020-02-12",
#     "description": "Recaps the bias concerns found in ImageNet",
#     "subject": "week-1;ethics;statement",
#     "language": "eng",
#     "URL": "https://engineering.princeton.edu/news/2020/02/12/researchers-devise-approach-reduce-biases-computer-vision-data-sets",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_021.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_021.html"
#   },
#   {
#     "title": "GitHub's automatic coding tool rests on untested legal ground",
#     "creator": "Gershgorn, D.",
#     "date": "2021-07-07",
#     "description": "Summary of how copilot is build on public code repositories",
#     "subject": "week-2;generative-AI;news",
#     "language": "eng",
#     "URL": "https://www.theverge.com/2021/7/7/22561180/github-copilot-legal-copyright-fair-use-public-code",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_022.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_022.html"
#   },
#   {
#     "title": "In Hollywood writers' battle against AI, humans win (for now)",
#     "creator": "Coyle, J.",
#     "date": "2023-09-27",
#     "description": "Summary of the AI concerns in the WGA strike from 2023",
#     "subject": "week-3;news;labour;news",
#     "language": "eng",
#     "URL": "https://apnews.com/article/hollywood-ai-strike-wga-artificial-intelligence-39ab72582c3a15f77510c9c30a45ffc8",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_023.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_023.html"
#   },
#   {
#     "title": "Introducing our AI Metadata Generator",
#     "creator": "Rose-Hellmann, I.",
#     "date": "2024-02-25",
#     "description": "Press release from ExLibris",
#     "subject": "week-4;news;generative-AI",
#     "language": "eng",
#     "URL": "https://exlibrisgroup.com/blog/artificial-intelligence-blog-series-introducing-our-ai-metadata-generator/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_024.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_024.html"
#   },
#   {
#     "title": "Exclusive: OpenAI Used Kenyan Workers on Less Than $2 Per Hour to Make ChatGPT Less Toxic",
#     "creator": "Perrigo, B.",
#     "date": "2023-01-18",
#     "description": "Outlines the working conditions of Kenyans who were hand checking ChatGPT transcripts",
#     "subject": "week-3;labour;generative-AI;news",
#     "language": "eng",
#     "URL": "https://time.com/6247678/openai-chatgpt-kenya-workers/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_025.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_025.html"
#   },
#   {
#     "title": "What is Retrival-Augmented Generation (RAG?)",
#     "creator": "IBM Technology",
#     "date": "2023-08-23",
#     "description": "6 minute video that describes the basics of RAG.",
#     "subject": "week-2;generative-AI;video",
#     "language": "eng",
#     "URL": "https://www.youtube.com/watch?v=T-D1OfcDW1M",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_026.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_026.html"
#   },
#   {
#     "title": "Stability AI reportedly ran out of cash to pay its bills for rented cloudy GPUs",
#     "creator": "Mann, T.",
#     "date": "2024-04-03",
#     "description": "Recounts how an AI company apparently ran out of funds to pay compute charges.",
#     "subject": "week-2;generative-AI;news",
#     "language": "eng",
#     "URL": "https://www.theregister.com/2024/04/03/stability_ai_bills/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_027.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_027.html"
#   },
#   {
#     "title": "How Large Language Models Work",
#     "creator": "IBM Technology",
#     "date": "2023-07-28",
#     "description": "Summary of how Large Language Modesl Function",
#     "subject": "week-2;generative-AI;video",
#     "language": "eng",
#     "URL": "https://www.youtube.com/watch?v=5sLYAQS9sWQ",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_028.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_028.html"
#   },
#   {
#     "title": "Neural Networks Explained in 5 minutes",
#     "creator": "IBM Technology",
#     "date": "2022-03-22",
#     "description": "Summary of how neural networks function",
#     "subject": "week-1;video",
#     "language": "eng",
#     "URL": "https://www.youtube.com/watch?v=jmmW0F0biz0",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_029.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_029.html"
#   },
#   {
#     "title": "Centaurs and Cyborgs on the Jagged Frontier",
#     "creator": "Mollick, Ethan",
#     "date": "2023-09-16",
#     "description": "Decribes what Mollick calls cyborg work where people augement their work with Large Language Models",
#     "subject": "week-3;generative-AI;blog",
#     "language": "eng",
#     "URL": "https://www.oneusefulthing.org/p/centaurs-and-cyborgs-on-the-jagged",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_030.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_030.html"
#   },
#   {
#     "title": "OpenAI establishes safety committee as new artificial intelligence model begins training",
#     "creator": "Associated Press",
#     "date": "2024-05-28",
#     "description": "Open AI announced that they will create a Safety and Security Committee.",
#     "subject": "openAI;safety;industry;news",
#     "language": "eng",
#     "URL": "https://www.pbs.org/newshour/nation/openai-establishes-safety-committee-as-new-artificial-intelligence-model-begins-training",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_031.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_031.html"
#   },
#   {
#     "title": "Global Affairs offers 'deepest regrets' to 'Inuit and Indigenous communities' over AI-generated image",
#     "creator": "Chase, S., Krikup, K.",
#     "date": "2023-12-14",
#     "description": "The Department of Global Affairs is apologizing for posting a picture generated by artificial intelligence to represent an Indigenous woman on social media.",
#     "subject": "equity;labour;news",
#     "language": "eng",
#     "URL": "https://www.theglobeandmail.com/politics/article-global-affairs-offers-deepest-regrets-to-inuit-and-indigenous/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_032.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_032.html"
#   },
#   {
#     "title": "An Alternative to Conventional Neural Networks Could Help Reveal What AI Is Doing behind the Scenes",
#     "creator": "Bischoff, M.",
#     "date": "2024-05-28",
#     "description": "This article is about a way to possibly make AI simpler and predictable - If Kolmogorov-Arnold networks (KANs) can be combined with AI (including LLMs, although these networks seem to be better suited for math), we may be able to understand how LLMs work.",
#     "subject": "ai;llm;black-box;news",
#     "language": "eng",
#     "URL": "https://www.scientificamerican.com/article/an-alternative-to-conventional-neural-networks-could-help-reveal-what-ai-is/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_033.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_033.html"
#   },
#   {
#     "title": "Developing responsible AI practices at the Smithsonian Institution",
#     "creator": "Dikow, R.B., DiPietro, C., et al.",
#     "date": "2023-10-25",
#     "description": "Many of us working with metadata are very interested in how AI tools can be used for resource description at a large scale. Artifacts (as opposed to textual documents) present a particular challenge for AI-generated metadata, and I appreciate how the Smithsonian took a serious look at potential bias in this area. Reading about their path toward creating an AI values statement was also enlightening.",
#     "subject": "machine-learning;metadata;ethics;article",
#     "language": "eng",
#     "URL": "https://riojournal.com/article/113334/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_034.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_034.html"
#   },
#   {
#     "title": "Many Americans think generative AI programs should credit the sources they rely on",
#     "creator": "Tyson, A., & Kennedy, B.",
#     "date": "2024-03-26",
#     "description": "The article brings up the very important question of whether or not sources should be cited by AI. Instead of focusing on the yes and no responses on citation, I feel like we should be talking about the third that are not sure AI should be cited. Are they skeptics, do they need more of an explanation of AI? What are their reasons?",
#     "subject": "generative-AI;chat-GPT;news",
#     "language": "eng",
#     "URL": "https://www.pewresearch.org/short-reads/2024/03/26/many-americans-think-generative-ai-programs-should-credit-the-sources-they-rely-on/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_035.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_035.html"
#   },
#   {
#     "title": "The ROBOT Test",
#     "creator": "sahervieux",
#     "date": "2020-03-11",
#     "description": "This resource encapsulates this course's perspective of skepticism in a succinct tool that helps librarians, patrons, and any AI user to evaluate AI products. The resource guides users not only to consider inherent biases in the tool, but also the ethics of the creators, and their own objectives for using the tool, in order to make informed and deliberate decisions about how they use AI.",
#     "subject": "ethics;resource;week-3;blog",
#     "language": "eng",
#     "URL": "https://thelibrairy.wordpress.com/2020/03/11/the-robot-test/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_036.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_036.html"
#   },
#   {
#     "title": "What Kind of Buble is AI?",
#     "creator": "Doctorow, C.",
#     "date": "2023-12-18",
#     "description": "In this article, Doctorow points out that while AI is good for low-stakes, fault-tolerant tasks, the money is in high-stakes, fault-intolerant tasks, which means that most of the things AI is marketed towards will be made worse (or more expensive, or both) through the addition of AI. I think this is a helpful way to think about how we use AI. Is this task fault-tolerant? Or is it easy to check for faults in the AI-work? If not, we probably shouldn't be using AI to do it. No matter whether AI is a bubble or not, this article gives a helpful way to test AI applications.",
#     "subject": "ai;Techbubble;cryptocurrency;blog",
#     "language": "eng",
#     "URL": "https://locusmag.com/2023/12/commentary-cory-doctorow-what-kind-of-bubble-is-ai/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_037.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_037.html"
#   },
#   {
#     "title": "The Environmental Impact of ChatGPT: A Call for Sustainable Practices In AI Development",
#     "creator": "Mclean, S.",
#     "date": "2023-04-28",
#     "description": "This article discusses the environmental impact of LLMs, specifically ChatGPT. It includes a critique of the lack of transparency in sharing data regarding the carbon footprint of AI data centers.",
#     "subject": "generative-AI;critique;resource",
#     "language": "eng",
#     "URL": "https://earth.org/environmental-impact-chatgpt/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_038.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_038.html"
#   },
#   {
#     "title": "Can generative AI facilitate the research process? It's complicated",
#     "creator": "Kingsley, D.",
#     "date": "2023-10-01",
#     "description": "This brief article outlines potental benefits and limitations of using generative AI in the research process and gives ideas for addressing some of the limitations. This resource could be helpful for library staff who are looking for ways to address AI and the research process in teaching, reference/consultations, etc.",
#     "subject": "generative-AI;research-process;news",
#     "language": "eng",
#     "URL": "https://crln.acrl.org/index.php/crlnews/article/view/26068",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_039.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_039.html"
#   },
#   {
#     "title": "The World of AI",
#     "creator": "Udell, E.",
#     "date": "2024-03-01",
#     "description": "This article provides a comprehensive overview of the multifaceted impact of artificial intelligence (AI) on libraries and society. It discusses the questions librarians have raised about AI (the article specifically focuses on Generative AI), highlighting ethical and legal (copyright) concerns along with the trustworthiness of AI-generated content.",
#     "subject": "generative-AI;ai-literacy;library;news",
#     "language": "eng",
#     "URL": "https://americanlibrariesmagazine.org/2024/03/01/the-world-of-ai/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_040.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_040.html"
#   },
#   {
#     "title": "Five Growing Concerns about Generative AI for Librarians and Information Professionals",
#     "creator": "Pfeiffer, D.",
#     "date": "2024-03-11",
#     "description": "This article shows the concerns and skeptics of AI to librarians and information specialists.",
#     "subject": "generative-AI;article;blog",
#     "language": "eng",
#     "URL": "https://www.choice360.org/libtech-insight/four-growing-concerns-about-generative-ai-for-librarians-and-information-professionals/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_041.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_041.html"
#   },
#   {
#     "title": "Generative AI's environmental costs are soaring - and mostly secret",
#     "creator": "Crawford, K.",
#     "date": "2024-02-20",
#     "description": "Describes a potential US-bill that would address the environmental costs of technology",
#     "subject": "generative-AI;sustainability;environment;article",
#     "language": "eng",
#     "URL": "https://www.nature.com/articles/d41586-024-00478-x",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_042.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_042.html"
#   },
#   {
#     "title": "Commentary / AI protections for librarian work: put it in the collective agreement?",
#     "creator": "Ribaric, T & Farnum, C.",
#     "date": "2024-09-01",
#     "description": "Editorial from the CAUT Bulletin that advocates for protections in collective agreements for librarian labour.",
#     "subject": "week-4;library;labour;generative-AI;blog",
#     "language": "eng",
#     "URL": "https://www.caut.ca/bulletin/ai-protections-for-librarian-work-put-it-in-the-collective-agreement/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_043.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_043.html"
#   },
#   {
#     "title": "Ex Libris Primo Research Assistant is now available for Primo institutions",
#     "creator": "ExLibris",
#     "date": "2024-09-25",
#     "description": "Press release from ExLibris",
#     "subject": "week-4;news;generative-AI",
#     "language": "eng",
#     "URL": "https://exlibrisgroup.com/announcement/ex-libris-primo-research-assistant-is-now-available-for-primo-institutions/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_044.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_044.html"
#   },
#   {
#     "title": "AI Snake Oil: What Artificial Intelligence Can Do, What It Can't, and How to Tell the Difference",
#     "creator": "Narayanan, A. & Kapoor, S.",
#     "date": "2024-09-24",
#     "description": "From two of TIME's 100 Most Influential People in AI, what you need to know about AI-and how to defend yourself against bogus AI claims and products",
#     "subject": "generative-AI;book",
#     "language": "eng",
#     "URL": "https://press.princeton.edu/books/hardcover/9780691249131/ai-snake-oil",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_045.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_045.html"
#   },
#   {
#     "title": "Generative AI and libraries: seven contexts",
#     "creator": "Dempsey, L.",
#     "date": "2023-11-12",
#     "description": "Post from a personal blog",
#     "subject": "generative-AI;blog",
#     "language": "eng",
#     "URL": "https://www.lorcandempsey.net/generative-ai-and-libraries-7-contexts/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_046.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_046.html"
#   },
#   {
#     "title": "Bridging the Gap Between Ethics and Practice: Guidelines for Reliable, Safe, and Trustworthy Human-centered AI Systems",
#     "creator": "Shneiderman, B.",
#     "date": "2020-10-16",
#     "description": "A research paper",
#     "subject": "governance;article",
#     "language": "eng",
#     "URL": "https://dl.acm.org/doi/abs/10.1145/3419764",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_048.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_047.html"
#   },
#   {
#     "title": "A new intermediary: How AI may impact libraries, research and information retrieval",
#     "creator": "DuBovis, N.",
#     "date": "2024-05-07",
#     "description": "This article shows the reactions of current librarians to implementing AI in their libraries.",
#     "subject": "job security;news",
#     "language": "eng",
#     "URL": "https://cronkitenews.azpbs.org/2024/05/07/ai-library-research-cataloging-information-retrieval-artificial-intelligence/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_048.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_048.html"
#   },
#   {
#     "title": "The Jovian Duck: LaMDA and the Mirror Test",
#     "creator": "Watts, P.",
#     "date": "2022-06-20",
#     "description": "Peter Watts (scifi author, biologist, and guy who blogged the process of dealing with flesh-eating bacteria) comments on the 2022 LaMDA controversy, when a Google software engineer claimed that Google's LLM had gained sentience. He discusses the idea of a \"Jovian Duck\".",
#     "subject": "ethics;AGI;critique;blog",
#     "language": "eng",
#     "URL": "https://www.rifters.com/crawl/?p=10269",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_049.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_049.html"
#   },
#   {
#     "title": "Responsible AI Practice in Libraries and Archives: A review of the Literature",
#     "creator": "Mannheimer et al.",
#     "date": "2024-09-23",
#     "description": "A literature review of the current uses of AI in libraries and archives and the ethical concerns being identified during these implementations.",
#     "subject": "ethics;paper;literature-review;",
#     "language": "eng",
#     "URL": "https://doi.org/10.5860/ital.v43i3.17245",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_050.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_050.html"
#   },
#   {
#     "title": "From ChatGPT to CatGPT: The implications of Artiricial Intelligence on Library Cataloguing",
#     "creator": "Brzustowicz",
#     "date": "2023-09-18",
#     "description": "According to the author, this paper examines ChatGPT's ability to streamline library cataloguing by generating accurate MARC records, showcasing its potential to improve efficiency. However, the author raises concerns about intellectual property and bias. He calls for further research to ensure responsible AI use in cataloguing.",
#     "subject": "generative-AI;cataloguing;paper",
#     "language": "eng",
#     "URL": "https://doi.org/10.5860/ital.v42i3.16295",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_051.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_051.html"
#   },
#   {
#     "title": "AI companies promised to self-regulate one year ago. What's changed?",
#     "creator": "Heikkila, M.",
#     "date": "2024-07-22",
#     "description": "The article provides a rationale for the need to regulate AI and provides a point-by-point analysis of recent developments in the field. Because it is based in part on interviews with the companies themselves, it provides first-hand information and goes beyond mere opinion.",
#     "subject": "industry;policy;news;",
#     "language": "eng",
#     "URL": "https://www.technologyreview.com/2024/07/22/1095193/ai-companies-promised-the-white-house-to-self-regulate-one-year-ago-whats-changed/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_052.jpg",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_052.html"
#   },
#   {
#     "title": "The Efficacy of ChatGPT: Is it Time for the Librarians to Go Home?",
#     "creator": "Kendrick, C.",
#     "date": "2023-01-26",
#     "description": "A skeptical look at the performance of the Jan. 2023 ChatGPT LLM interactions with research questions that typical for librarians. The writer, who is a librarian, gives us a good--if somewhat dated--view of how generative AI can end up producing many flawed citations that are especially misleading because they're well formed. Since this article was published the problem of AI hallucinations in aiding research, as a human librarian would, has yet to be solved.",
#     "subject": "generative-AI;hallucination;blog",
#     "language": "eng",
#     "URL": "https://scholarlykitchen.sspnet.org/2023/01/26/guest-post-the-efficacy-of-chatgpt-is-it-time-for-the-librarians-to-go-home/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_053.jpg",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_053.html"
#   },
#   {
#     "title": "Why AI doesn't speak every language",
#     "creator": "Vox Media",
#     "date": "2023-04-11",
#     "description": "The video explores the difficulties that large language models (LLMs) like GPT-3 and GPT-4 encounter, especially with low-resource languages. It outlines how LLMs function, utilizing natural language processing for tasks such as sentiment analysis, summarization, and translation. The video emphasizes the disparity in language representation within these models, noting a significant focus on high-resource languages like English and German, while languages like Jamaican patois and Catalan are often overlooked. Researchers are striving to create datasets for these lesser-known languages to enhance model comprehension and performance. Additionally, the video discusses initiatives to develop open-source multilingual models, such as Hugging Face's BLOOM, to mitigate these imbalances.",
#     "subject": "generative-AI;bias;video",
#     "language": "eng",
#     "URL": "https://youtu.be/a2DgdsE86ts",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_054.jpg",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_054.html"
#   },
#   {
#     "title": "Wiley Leans into AI. The Community Should Lean with Them.",
#     "creator": "Carpenter, T.",
#     "date": "2024-10-31",
#     "description": "This is a wide ranging interview on AI development by the head of NISO, Todd Carpenter and the head of AI at Wiley, Josh Jarrett. The interview speak about the responsibility of publishers to serve the majority of authors who are looking to the publishers to develop and creat the standards on use of AI in the scholarly publishing landscape. ",
#     "subject": "generative-AI;ethics;RAG;blog",
#     "language": "eng",
#     "URL": "https://scholarlykitchen.sspnet.org/2024/10/31/wileys-josh-jarret-interview-about-impact-of-ai/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_055.jpg",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_055.html"
#   },
#   {
#     "title": "Should you feel guilty about using AI?",
#     "creator": "Estes, A. C.",
#     "date": "2024-11-01",
#     "description": "This article of Nov. 1, 2024 addresses ethical and environmental issues of AI usage, including its transparency and sustainability.",
#     "subject": "ethics;environment;blog",
#     "language": "eng",
#     "URL": "https://www.vox.com/technology/381158/should-you-feel-guilty-about-using-ai",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_056.jpg",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_056.html"
#   },
#   {
#     "title": "Annif",
#     "creator": "Annif",
#     "date": "2024-12-12",
#     "description": "Annif is an open source toolkit for automated subject indexing. It integrates several machine learning and AI based algorithms for text classification. Annif uses a combination of existing natural language processing and machine learning tools including TensorFlow, Omikuji, fastText and Gensim.",
#     "subject": "generative-AI;indexing;software",
#     "language": "eng",
#     "URL": "https://annif.org/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_057.jpg",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_057.html"
#   },
#   {
#     "title": "Information Literacy and Chabots as Search",
#     "creator": "Bender, E. M.",
#     "date": "2024-11-05",
#     "description": "Blog post from Mystery AI Hype Theatre 3000",
#     "subject": "LLM;critique;AI-literacy;generative-AI;ethics;blog",
#     "language": "eng",
#     "URL": "https://buttondown.com/maiht3k/archive/information-literacy-and-chatbots-as-search/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_058.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_058.html"
#   },
#   {
#     "title": "The AI Con",
#     "creator": "Bender, E.M. & Hanna, A.",
#     "date": "2025-01-01",
#     "description": "Homepage for the book: The AI Con",
#     "subject": "generative-ai;bias;book;",
#     "language": "eng",
#     "URL": "https://thecon.ai/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_059.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_059.html"
#   },
#   {
#     "title": "A Librarian Against AI",
#     "creator": "Fox, V.",
#     "date": "2025-01-01",
#     "description": "A zine that presents a critical case against AI in libraries",
#     "subject": "ethics;critique;zine",
#     "language": "eng",
#     "URL": "https://violetbfox.info/against-ai/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_060.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_060.html"
#   },
#   {
#     "title": "Why This School District Used A.I. to Help Determine Which Books to Ban",
#     "creator": "Kuta, S.",
#     "date": "2023-08-21",
#     "description": "Describes how a library system in Iowa used AI as part of a weeding exercise",
#     "subject": "weeding;ethics;blog",
#     "language": "eng",
#     "URL": "https://www.smithsonianmag.com/smart-news/why-this-school-district-used-ai-to-help-remove-library-books-180982762/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_0XX.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_061.html"
#   },
#   {
#     "title": "Intro to AI agents",
#     "creator": "Google Cloud Tech",
#     "date": "2024-11-14",
#     "description": "Video introducing the concept of AI agents",
#     "subject": "agentic-AI;video",
#     "language": "eng",
#     "URL": "https://www.youtube.com/watch?v=ZZ2QUCePgYw",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_0XX.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_062.html"
#   },
#   {
#     "title": "Being honest about using AI at work makes people trust you less, research finds",
#     "creator": "Schilke, O & Reimann, M.",
#     "date": "2025-05-06",
#     "description": "A blog post from The Conversation on the topic of perceptions of AI use",
#     "subject": "ethics;policy;industry;blog",
#     "language": "eng",
#     "URL": "https://theconversation.com/being-honest-about-using-ai-at-work-makes-people-trust-you-less-research-finds-253590",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_063.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_063.html"
#   },
#   {
#     "title": "Tips and Trends: AI Developments and Resources for Academic Librarians",
#     "creator": "Martin, J. & Armstrong, M.",
#     "date": "2024-04-12",
#     "description": "A blog post from ARCL on tips for academic librarians",
#     "subject": "academic-liraries;blog",
#     "language": "eng",
#     "URL": "https://acrl.ala.org/IS/tips-and-trends-ai-developments-and-resources-for-academic-librarians/",
#     "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_064.png",
#     "object_location": "",
#     "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_064.html"
#   }
# ]

# %% [markdown]
# ###Picking a specific item in the JSON output
#
# We can use the skills we developed in the indexing section to select certain items from our JSON data. You can see that the data looks like a dictionary. It have a key and value.

# %%
#The first JSON object in our object using the slice operator
data_index = 0
print(json.dumps(objects_cb_data[data_index],indent=2))
# Out:
# {
#   "title": "On the Dangers of Stochastic Parrots: Can Language Models Be Too Big? \ud83e\udd9c",
#   "creator": "Bender, M. Emily; Gebru, Timnit; McMillian-Major; Shmitchell, Shmargaret",
#   "date": "2021-03-01",
#   "description": "The past 3 years of work in NLP have been characterized by the development and deployment of ever larger language models, especially for English. BERT, its variants, GPT-2/3, and others, most recently Switch-C, have pushed the boundaries of the possible both through architectural innovations and through sheer size. Using these pretrained models and the methodology of fine-tuning them for specific tasks, researchers have extended the state of the art on a wide array of tasks as measured by leaderboards on specific benchmarks for English. In this paper, we take a step back and ask: How big is too big? What are the possible risks associated with this technology and what paths are available for mitigating those risks? We provide recommendations including weighing the environmental and financial costs first, investing resources into curating and carefully documenting datasets rather than ingesting everything on the web, carrying out pre-development exercises evaluating how the planned approach fits into research and development goals and supports stakeholder values, and encouraging research directions beyond ever larger language models.",
#   "subject": "generative-AI;paper",
#   "language": "eng",
#   "URL": "https://doi.org/10.1145/3442188.3445922",
#   "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_001.png",
#   "object_location": "",
#   "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_001.html"
# }

# %%
# All the keys in the first item using the slice operator
for item in objects_cb_data[data_index].keys():
  print(item)
# Out:
# title
# creator
# date
# description
# subject
# language
# URL
# object_thumb
# object_location
# reference_url

# %%
#Print all the values in the first item using the slice operator
for item in objects_cb_data[data_index].values():
  print(item)
# Out:
# On the Dangers of Stochastic Parrots: Can Language Models Be Too Big? 🦜
# Bender, M. Emily; Gebru, Timnit; McMillian-Major; Shmitchell, Shmargaret
# 2021-03-01
# The past 3 years of work in NLP have been characterized by the development and deployment of ever larger language models, especially for English. BERT, its variants, GPT-2/3, and others, most recently Switch-C, have pushed the boundaries of the possible both through architectural innovations and through sheer size. Using these pretrained models and the methodology of fine-tuning them for specific tasks, researchers have extended the state of the art on a wide array of tasks as measured by leaderboards on specific benchmarks for English. In this paper, we take a step back and ask: How big is too big? What are the possible risks associated with this technology and what paths are available for mitigating those risks? We provide recommendations including weighing the environmental and financial costs first, investing resources into curating and carefully documenting datasets rather than ingesting everything on the web, carrying out pre-development exercises evaluating how the planned approach fits into research and development goals and supports stakeholder values, and encouraging research directions beyond ever larger language models.
# generative-AI;paper
# eng
# https://doi.org/10.1145/3442188.3445922
# https://elibtronic.github.io/AIL_Database/objects/ail_001.png
#
# https://elibtronic.github.io/AIL_Database/items/ail_001.html

# %% [markdown]
# **Q4** Print the contents of the 10th item in the JSON data in the cell below

# %%
#Q4
data_index = 9
print(json.dumps(objects_cb_data[data_index],indent=2))
# Out:
# {
#   "title": "How an Iowa School District Used ChatGPT to Ban Books",
#   "creator": "Watercutter, A.",
#   "date": "2020-01-01",
#   "description": "Recalls the story of how ChatGPT was used to aid in a weeding exercise.",
#   "subject": "week-3;ethics;news",
#   "language": "eng",
#   "URL": "https://www.wired.com/story/chatgpt-ban-books-iowa-schools-sf-496/",
#   "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_010.png",
#   "object_location": "",
#   "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_010.html"
# }

# %% [markdown]
# **Q5**
#
# Run the cell below and try to grab a random item from the data....

# %%
#Q5

#we pull in a function from the random library
from random import randrange
#we create a random integer somewhere in the range of 0 to length of objects
random_entry = randrange(len(objects_cb_data))
#Now we print the JSON data at that random index
print(json.dumps(objects_cb_data[random_entry],indent=2))
# Out:
# {
#   "title": "Bridging the Gap Between Ethics and Practice: Guidelines for Reliable, Safe, and Trustworthy Human-centered AI Systems",
#   "creator": "Shneiderman, B.",
#   "date": "2020-10-16",
#   "description": "A research paper",
#   "subject": "governance;article",
#   "language": "eng",
#   "URL": "https://dl.acm.org/doi/abs/10.1145/3419764",
#   "object_thumb": "https://elibtronic.github.io/AIL_Database/objects/ail_048.png",
#   "object_location": "",
#   "reference_url": "https://elibtronic.github.io/AIL_Database/items/ail_047.html"
# }

# %% [markdown]
# **Q5 continued**
#
# In the cell below copy and paste the link that will take you to the web display of the random item displayed above

# %%
#Q5 continued
reference_url = "https://elibtronic.github.io/AIL_Database/items/ail_040.html"

print("You can view the web display of this item here: " + reference_url)
# Out:
# You can view the web display of this item here: https://elibtronic.github.io/AIL_Database/items/ail_040.html

# %% [markdown]
# ##Subject information from a CollectionBuilder site
#
# One of the API _end points_ from CollectionBuilder is a listing of the subjects in the dataset. Up until this point we were looking at the completed list of metadata in the site.
#
# The following few cells look just at the subject JSON. Try looking at the [Subjects JSON URL](https://elibtronic.github.io/AIL_Database/assets/data/subjects.json) using just your browser

# %%
# @title URL of JSON file for subjects only in CollectionBuilder {"run":"auto","display-mode":"form"}

json_subjects_url = "https://elibtronic.github.io/AIL_Database/assets/data/subjects.json" # @param {"type":"string","placeholder":"https://elibtronic.github.io/AIL_Database/assets/data/subjects.json"}
# @markdown Feel free to change this to a different Collection Builder Subject JSON URL. (Heads up: You'll be doing this for your homework this week)


response_subjects = requests.get(json_subjects_url)
total_subject_data = response_subjects.json()
subject_cb_data = total_subject_data['subjects']

# %%
# print just the first item in the subjects JSON object
subject_index = 0
print(json.dumps(subject_cb_data[subject_index],indent=2))
# Out:
# {
#   "subject": "generative-ai",
#   "count": 30,
#   "link": "https://elibtronic.github.io/AIL_Database/browse.html#generative-ai"
# }

# %% [markdown]
# ## Subject Counts
#
# We can now grab all of the subject names and corresponding counts how how often they were used and print them to the screen. We'll be using a Python `dictionary` as part of this work.

# %%
#A dictionary variable that will hold our key value combination of
#subject name and count
subject_frequency = {}

#Change JSON data into a dictionary
for item in subject_cb_data:
  subject_frequency[item['subject']] = item['count']


for key,value in subject_frequency.items():
  print("Subject label: "+ str(key) + ", shows up " + str(value) + " times in the data")
# Out:
# Subject label: generative-ai, shows up 30 times in the data
# Subject label: ethics, shows up 17 times in the data
# Subject label: news, shows up 17 times in the data
# Subject label: blog, shows up 14 times in the data
# Subject label: library, shows up 13 times in the data
# Subject label: paper, shows up 8 times in the data
# Subject label: week-2, shows up 8 times in the data
# Subject label: video, shows up 7 times in the data
# Subject label: week-3, shows up 7 times in the data
# Subject label: week-1, shows up 6 times in the data
# Subject label: critique, shows up 6 times in the data
# Subject label: resource, shows up 6 times in the data
# Subject label: statement, shows up 5 times in the data
# Subject label: week-4, shows up 5 times in the data
# Subject label: labour, shows up 4 times in the data
# Subject label: article, shows up 4 times in the data
# Subject label: policy, shows up 3 times in the data
# Subject label: industry, shows up 3 times in the data
# Subject label: agi, shows up 2 times in the data
# Subject label: chapter, shows up 2 times in the data
# Subject label: ai, shows up 2 times in the data
# Subject label: llm, shows up 2 times in the data
# Subject label: ai-literacy, shows up 2 times in the data
# Subject label: environment, shows up 2 times in the data
# Subject label: book, shows up 2 times in the data
# Subject label: bias, shows up 2 times in the data
# Subject label: book-review, shows up 1 times in the data
# Subject label: poll, shows up 1 times in the data
# Subject label: openai, shows up 1 times in the data
# Subject label: safety, shows up 1 times in the data
# Subject label: equity, shows up 1 times in the data
# Subject label: black-box, shows up 1 times in the data
# Subject label: machine-learning, shows up 1 times in the data
# Subject label: metadata, shows up 1 times in the data
# Subject label: chat-gpt, shows up 1 times in the data
# Subject label: techbubble, shows up 1 times in the data
# Subject label: cryptocurrency, shows up 1 times in the data
# Subject label: research-process, shows up 1 times in the data
# Subject label: sustainability, shows up 1 times in the data
# Subject label: governance, shows up 1 times in the data
# Subject label: job security, shows up 1 times in the data
# Subject label: literature-review, shows up 1 times in the data
# Subject label: cataloguing, shows up 1 times in the data
# Subject label: hallucination, shows up 1 times in the data
# Subject label: rag, shows up 1 times in the data
# Subject label: indexing, shows up 1 times in the data
# Subject label: software, shows up 1 times in the data
# Subject label: zine, shows up 1 times in the data
# Subject label: weeding, shows up 1 times in the data
# Subject label: agentic-ai, shows up 1 times in the data
# Subject label: academic-liraries, shows up 1 times in the data

# %% [markdown]
# **Q6** Which subject shows up the most in the data?

# %%
#Q6
most_subject = "generative-ai"
print("The subject that comes up the most is " + most_subject)
# Out:
# The subject that comes up the most is generative-ai

# %% [markdown]
# ## Moral of the story
#
# JSON is just one way to represent data that has keys and values. So, we can put JSON data into a pandas dataframe just like a spreadsheet. Run the cells below the see a couple of dataframes of the information from this site.
#
# In the next cell we try to put each JSON entry into a new record in our dataframe. It doesn't look that nice.

# %%
#That doesn't look nice!
subjects_df = pd.read_json(json_cb_url)
subjects_df
# Out:
#                                               objects
# 0   {'title': 'On the Dangers of Stochastic Parrot...
# 1   {'title': 'What do we mean by equitable and ac...
# 2   {'title': 'Can we build AI without losing cont...
# 3   {'title': 'Learn to Take on the Ceiling', 'cre...
# 4   {'title': 'We need a manifesto for Responsible...
# ..                                                ...
# 59  {'title': 'A Librarian Against AI', 'creator':...
# 60  {'title': 'Why This School District Used A.I. ...
# 61  {'title': 'Intro to AI agents', 'creator': 'Go...
# 62  {'title': 'Being honest about using AI at work...
# 63  {'title': 'Tips and Trends: AI Developments an...
#
# [64 rows x 1 columns]

# %% [markdown]
# ## 'Normalizing' first
#
# We can normalize the JSON first before we try to make it into a dataframe. That way Pandas will know that the key value combination needs to be put in the column and the row for each piece of data.
#
# Run the next cell to see the data changed into a _proper_ dataframe.

# %%
#We'll normalize to get Pandas to try to 'shape' the data
normalized_df = pd.json_normalize(subjects_df['objects'])
normalized_df
# Out:
#                                                 title  \
# 0   On the Dangers of Stochastic Parrots: Can Lang...
# 1    What do we mean by equitable and accountable AI?
# 2     Can we build AI without losing control over it?
# 3                        Learn to Take on the Ceiling
# 4              We need a manifesto for Responsible AI
# ..                                                ...
# 59                             A Librarian Against AI
# 60  Why This School District Used A.I. to Help Det...
# 61                                 Intro to AI agents
# 62  Being honest about using AI at work makes peop...
# 63  Tips and Trends: AI Developments and Resources...
#
#                                               creator        date  \
# 0   Bender, M. Emily; Gebru, Timnit; McMillian-Maj...  2021-03-01
# 1                            Algorithm Justice League  2024-02-14
# 2                                         Harris, Sam  2024-02-14
# 3                                            Reben, A  2021-01-01
# 4      CILIP: the library and information association  2023-09-07
# ..                                                ...         ...
# 59                                            Fox, V.  2025-01-01
# 60                                           Kuta, S.  2023-08-21
# 61                                  Google Cloud Tech  2024-11-14
# 62                           Schilke, O & Reimann, M.  2025-05-06
# 63                         Martin, J. & Armstrong, M.  2024-04-12
#
#                                           description  \
# 0   The past 3 years of work in NLP have been char...
# 1   Provides definition and description of equitab...
# 2   Harris is a neuroscientist and philosopher,  t...
# 3                     Reading found on page 105 - 114
# 4   Speech given by the CEO of Chartered Institute...
# ..                                                ...
# 59  A zine that presents a critical case against A...
# 60  Describes how a library system in Iowa used AI...
# 61         Video introducing the concept of AI agents
# 62  A blog post from The Conversation on the topic...
# 63  A blog post from ARCL on tips for academic lib...
#
#                                   subject language  \
# 0                     generative-AI;paper      eng
# 1                 week-1;ethics;statement      eng
# 2                 week-1;ethics;agi;video      eng
# 3   week-1;generative-AI;critique;chapter      eng
# 4                week-1;statement;library      eng
# ..                                    ...      ...
# 59                   ethics;critique;zine      eng
# 60                    weeding;ethics;blog      eng
# 61                       agentic-AI;video      eng
# 62            ethics;policy;industry;blog      eng
# 63                 academic-liraries;blog      eng
#
#                                                   URL  \
# 0             https://doi.org/10.1145/3442188.3445922
# 1                      https://www.ajl.org/learn-more
# 2         https://www.youtube.com/watch?v=8nt3edWLgIg
# 3                  http://archive.org/details/fake-ai
# 4   https://www.cilip.org.uk/news/650937/We-need-a...
# ..                                                ...
# 59                https://violetbfox.info/against-ai/
# 60  https://www.smithsonianmag.com/smart-news/why-...
# 61        https://www.youtube.com/watch?v=ZZ2QUCePgYw
# 62  https://theconversation.com/being-honest-about...
# 63  https://acrl.ala.org/IS/tips-and-trends-ai-dev...
#
#                                          object_thumb object_location  \
# 0   https://elibtronic.github.io/AIL_Database/obje...
# 1   https://elibtronic.github.io/AIL_Database/obje...
# 2   https://elibtronic.github.io/AIL_Database/obje...
# 3   https://elibtronic.github.io/AIL_Database/obje...
# 4   https://elibtronic.github.io/AIL_Database/obje...
# ..                                                ...             ...
# 59  https://elibtronic.github.io/AIL_Database/obje...
# 60  https://elibtronic.github.io/AIL_Database/obje...
# 61  https://elibtronic.github.io/AIL_Database/obje...
# 62  https://elibtronic.github.io/AIL_Database/obje...
# 63  https://elibtronic.github.io/AIL_Database/obje...
#
#                                         reference_url
# 0   https://elibtronic.github.io/AIL_Database/item...
# 1   https://elibtronic.github.io/AIL_Database/item...
# 2   https://elibtronic.github.io/AIL_Database/item...
# 3   https://elibtronic.github.io/AIL_Database/item...
# 4   https://elibtronic.github.io/AIL_Database/item...
# ..                                                ...
# 59  https://elibtronic.github.io/AIL_Database/item...
# 60  https://elibtronic.github.io/AIL_Database/item...
# 61  https://elibtronic.github.io/AIL_Database/item...
# 62  https://elibtronic.github.io/AIL_Database/item...
# 63  https://elibtronic.github.io/AIL_Database/item...
#
# [64 rows x 10 columns]

# %% [markdown]
# ## Homework Time
#
# Head over to the homework to analyze a Collection Builder site of your choosing!
