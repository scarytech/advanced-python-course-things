# %% [markdown]
# <a href="https://colab.research.google.com/github/scarytech/advanced-python-course-things/blob/main/Sara_Sladwick_Week_1_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Homework
#
# (Be sure to save this to Drive before starting)
#
# For this week we are going to practice requesting information from an API and manipulating it as JSON and as a Dataframe.
#
# We are going to keep working with Collection Builder. Head over to the [Collection Builder Example Projects](https://collectionbuilder.github.io/cb-examples/browse.html) listing and find a site that interests you. Spend some time browsing the website to get acquainted with its contents before proceeding with the questions.

# %%
#The Libraries we will need
import requests
import json
import pandas as pd
from random import randrange

# %%
# @markdown **H1** Find the URL of for the  _metadata.json_ of your selected site and paste it in here.
json_cb_url = "https://johaknigiu.github.io/Digital-Videogame-Art-Scan-Project/assets/data/metadata.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
objects_cb_data = total_cb_data['objects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# **H2** Run the 'show random cell' a few times to get a sense of what kind of data is in your chosen site.

# %%
#Run this a few times to see random entries in the JSON data that you retrieved.
random_entry = randrange(len(objects_cb_data))
print(json.dumps(objects_cb_data[random_entry],indent=2))
# Out:
# {
#   "title": "Sonic Adventure 2 Box Art",
#   "media-type": "Box Art",
#   "format": "application/pdf",
#   "platform": "Sega Dreamcast",
#   "publisher": "Sega",
#   "gameid": "Sonic Adventure 2 ",
#   "creator": "Sega of America;Yuji Uekawa",
#   "date": "2001",
#   "objectid": "dcsa2b.pdf",
#   "filename": "DcSA2b.pdf",
#   "language": "English",
#   "description": "This is the packaging and accompanying box artwork for Sonic Adventure 2. It lists general information and features of the game intended to entice consumers as well as listing requirements and system features present for the game. This box also holds the game and instruction manual. Dreamcast games use the instruction manuals as the front box art. This partciular copy of the game features an autograph from one of the band members that wrote music for the game. ",
#   "franchise": "Sonic the Hedgehog ",
#   "genre": "Platform;Action",
#   "rights": "Material protected under copyright; Using under fair use; if this material is considered damaging or offensive to the copyright owner this material will be taken down upon request. ",
#   "youtube-link": "https://www.youtube.com/watch?v=KYvX3VVzUys",
#   "reference_url": "https://johaknigiu.github.io/Digital-Videogame-Art-Scan-Project/item.html?id=dcsa2b.pdf"
# }

# %% [markdown]
# ## Different Fields!
#
# You can create any number of datafields and correpsonding values for those fields with a Collection Builder site. So the results from the output from the cell above will probably have wildly different results from [my site](https://elibtronic.github.io/AIL_Database/data.html) that we worked on in the Workalong notebook.
#
#
# You can see all of these options from grabbing the _facets.json_ URL from a collection builder homepage. Find that URL for your selected site for **H3**

# %%
# @markdown **H3** Find the URL of the facets.json for your selected site and paste it in here.
json_cb_facets_url = "https://johaknigiu.github.io/Digital-Videogame-Art-Scan-Project/assets/data/facets.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_facets_url)
#all of the data from the sites
total_facet_data = response_cb.json()
#just the 'objects' indexed in the site
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# Run the cell below to see what the facets used for this site:

# %%
print(json.dumps(total_facet_data,indent=2))
# Out:
# {
#   "facets": [
#     {
#       "field": "mediatype",
#       "terms": {}
#     },
#     {
#       "field": "platform",
#       "terms": {
#         "nintendo ds": 12,
#         "nintendo gamecube": 20,
#         "sega dreamcast": 15,
#         "sega genesis": 11,
#         "sega genesis/cd": 3
#       }
#     },
#     {
#       "field": "publisher",
#       "terms": {
#         "amusmant vision": 3,
#         "chunsoft": 3,
#         "factor 5": 1,
#         "factor 6": 1,
#         "factor 7": 1,
#         "game freak": 3,
#         "hal laboratory": 3,
#         "lucasarts": 3,
#         "nintendo": 29,
#         "sega": 29,
#         "the pokemon company": 6,
#         "virgin interactive": 3
#       }
#     },
#     {
#       "field": "gameid",
#       "terms": {
#         "animal crossing": 4,
#         "animal crossing wild world": 3,
#         "arnold palmer's tournament golf": 2,
#         "caesar's palace": 3,
#         "fzero gx": 3,
#         "mario kart ds": 3,
#         "phantasy star online ver. 2": 3,
#         "pokemon mystery dungeon: explorers of sky": 3,
#         "pokemon platinum version": 3,
#         "sega marine fishing": 3,
#         "sega sports world series baseball 2k2": 3,
#         "sonic adventure": 3,
#         "sonic adventure 2": 3,
#         "sonic cd": 3,
#         "sonic the hedgehog": 3,
#         "sonic the hedgehog 3": 3,
#         "star wars rogue leader rogue squadron ii": 3,
#         "super mario sunshine": 3,
#         "super smash bros. melee": 3,
#         "system": 1,
#         "the legend of zelda twilight princess": 3
#       }
#     }
#   ]
# }

# %% [markdown]
# **H3** Try to read the JSON that is displayed to the screen. What possible facets are there in the the data. Fill them in the markdown list in the cell below. Add as many entries as you need to describe the site

# %% [markdown]
# Facets in my site are:
# - mediatype
# - platform
# - publisher
# - gameid

# %% [markdown]
# **H4** Which facet shows up the most for your selected site? Put your answer in the cell below

# %% [markdown]
# This facet that shows up the most is gameid it is used 21 times on my selected site.

# %% [markdown]
# **H5** Turn the site _metadata.json_ data into a dataframe by completing the cell below. Part of it is written for you. You just need to modify line 4.

# %%
#H5

cb_data = pd.read_json(json_cb_url)
cb_normalized= pd.json_normalize(cb_data['objects'])
cb_normalized
# Out:
#                                                 title  media-type  \
# 0             Arnold Palmer's Tournament Golf Box Art     Box Art
# 1                          Sonic the Hedgehog Box Art     Box Art
# 2                             Caesar's Palace Box Art     Box Art
# 3                        Sonic the Hedgehog 3 Box Art     Box Art
# 4                                    Sonic CD Box Art     Box Art
# ..                                                ...         ...
# 56  Pokemon Mystery Dungeon: Explorers of Sky Cart...  Cartridge
# 57                              Mario Kart DS Manual      Manual
# 58                 Animal Crossing Wild World Manual      Manual
# 59                   Pokemon Platinum Version Manual      Manual
# 60  Pokemon Mystery Dungeon: Explorers of Sky Manual      Manual
#
#              format         platform  \
# 0   application/pdf    Sega Genesis
# 1   application/pdf    Sega Genesis
# 2   application/pdf    Sega Genesis
# 3   application/pdf    Sega Genesis
# 4   application/pdf  Sega Genesis/CD
# ..              ...              ...
# 56       image/jpeg     Nintendo DS
# 57  application/pdf     Nintendo DS
# 58  application/pdf     Nintendo DS
# 59  application/pdf     Nintendo DS
# 60  application/pdf     Nintendo DS
#
#                                    publisher  \
# 0                                       Sega
# 1                                       Sega
# 2                        Virgin Interactive
# 3                                       Sega
# 4                                       Sega
# ..                                       ...
# 56     Chunsoft;The Pokemon Company;Nintendo
# 57                                 Nintendo
# 58                                 Nintendo
# 59  Nintendo;Game Freak;The Pokemon Company
# 60    Chunsoft;The Pokemon Company; Nintendo
#
#                                         gameid  \
# 0             Arnold Palmer's Tournament Golf
# 1                          Sonic the Hedgehog
# 2                              Caesar's Palace
# 3                         Sonic the Hedgehog 3
# 4                                     Sonic CD
# ..                                         ...
# 56  Pokemon Mystery Dungeon: Explorers of Sky
# 57                               Mario Kart DS
# 58                 Animal Crossing Wild World
# 59                   Pokemon Platinum Version
# 60  Pokemon Mystery Dungeon: Explorers of Sky
#
#                                               creator        date  \
# 0                                     Sega of America        1989
# 1                         Sega of America;Greg Martin  1991; 1992
# 2                                 Virgin Interactive         1993
# 3                         Sega of America;Greg Martin        1994
# 4                         Sega of America;Greg Martin        1993
# ..                                                ...         ...
# 56            The Pokemon Company;Nintendo of America        2009
# 57                                Nintendo of America        2005
# 58                                Nintendo of America        2005
# 59  Ken Sugamori;Game Freak;The Pokemon Company;Ni...        2009
# 60  Ken Sugamori;Chun Soft;The Pokemon Company;Nin...        2009
#
#          objectid       filename language  \
# 0     sgaptgb.pdf    SgAPTGb.pdf  English
# 1      sgsthb.pdf     SgSTHb.pdf  English
# 2       sgcpb.pdf      SgCPb.pdf  English
# 3     sgsth3b.pdf    SgSTH3b.pdf  English
# 4      sgscdb.pdf     SgSCDb.pdf  English
# ..            ...            ...      ...
# 56  dspmdeosc.jpg  DsPMDEOSc.jpg  English
# 57    dsmkdsm.pdf    DsMKDSm.pdf  English
# 58    dsacwwm.pdf    DsACWWm.pdf  English
# 59     dsppvm.pdf     DsPPVm.pdf  English
# 60  dspmdeosm.pdf  DsPMDEOSm.pdf  English
#
#                                           description  \
# 0   This is the packaging and accompanying box art...
# 1   This is the packaging and accompanying box art...
# 2   This is the packaging and accompanying box art...
# 3   This is the packaging and accompanying box art...
# 4   This is the packaging and accompanying box art...
# ..                                                ...
# 56  This is the physical storage cartridge for Pok...
# 57  This is the instruction manual for Mario Kart ...
# 58  This is the instruction manual for Animal Cros...
# 59  This is the instruction manual for Pokemon Pla...
# 60  This is the instruction manual for Pokemon Mys...
#
#                             franchise                    genre  \
# 0                                 N/A                   Sports
# 1                 Sonic the Hedgehog           Platform;Action
# 2                    Caesar's Palace                  Gambling
# 3                 Sonic the Hedgehog           Platform;Action
# 4                 Sonic the Hedgehog           Platform;Action
# ..                                ...                      ...
# 56  Pokemon; Pokemon Mystery Dungeon   Japanese RPG;Rogue-Like
# 57      Super Mario Bros; Mario Kart                    Racing
# 58                   Animal Crossing          Social Simulator
# 59                           Pokemon              Japanese RPG
# 60  Pokemon; Pokemon Mystery Dungeon   Japanese RPG;Rogue-Like
#
#                                                rights  \
# 0   Material protected under copyright; Using unde...
# 1   Material protected under copyright; Using unde...
# 2   Material protected under copyright; Using unde...
# 3   Material protected under copyright; Using unde...
# 4   Material protected under copyright; Using unde...
# ..                                                ...
# 56  Material protected under copyright; Using unde...
# 57  Material protected under copyright; Using unde...
# 58  Material protected under copyright; Using unde...
# 59  Material protected under copyright; Using unde...
# 60  Material protected under copyright; Using unde...
#
#                                          youtube-link  \
# 0         https://www.youtube.com/watch?v=FkVJ7ES_y30
# 1   https://www.youtube.com/watch?v=BETxNmSMNMc&li...
# 2         https://www.youtube.com/watch?v=Mg0W1kE_pzs
# 3         https://www.youtube.com/watch?v=Q260BqrWHgo
# 4         https://www.youtube.com/watch?v=ct6hfxnShDE
# ..                                                ...
# 56        https://www.youtube.com/watch?v=32rPL935tgI
# 57        https://www.youtube.com/watch?v=CJ-xwo5TvH0
# 58        https://www.youtube.com/watch?v=rhn4kNkrX48
# 59        https://www.youtube.com/watch?v=w5VyM7S56GU
# 60        https://www.youtube.com/watch?v=32rPL935tgI
#
#                                   internetarchivelink  \
# 0   https://archive.org/details/Arnold_Palmer_Tour...
# 1              https://archive.org/details/sonic1_bin
# 2                                                 NaN
# 3               https://archive.org/details/sonic_bin
# 4                                                 NaN
# ..                                                ...
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
#
#                                         reference_url
# 0   https://johaknigiu.github.io/Digital-Videogame...
# 1   https://johaknigiu.github.io/Digital-Videogame...
# 2   https://johaknigiu.github.io/Digital-Videogame...
# 3   https://johaknigiu.github.io/Digital-Videogame...
# 4   https://johaknigiu.github.io/Digital-Videogame...
# ..                                                ...
# 56  https://johaknigiu.github.io/Digital-Videogame...
# 57  https://johaknigiu.github.io/Digital-Videogame...
# 58  https://johaknigiu.github.io/Digital-Videogame...
# 59  https://johaknigiu.github.io/Digital-Videogame...
# 60  https://johaknigiu.github.io/Digital-Videogame...
#
# [61 rows x 18 columns]

# %%
#Run this a few times to see random entries in your dataframe
cb_normalized.sample(10)
# Out:
#                                                 title  media-type  \
# 46      The Legend of Zelda Twilight Princess Manual      Manual
# 21                           Sega Marine Fishing Disc        Disc
# 0             Arnold Palmer's Tournament Golf Box Art     Box Art
# 24                            Sonic Adventure Manual      Manual
# 56  Pokemon Mystery Dungeon: Explorers of Sky Cart...  Cartridge
# 50                 Animal Crossing Wild World Box Art     Box Art
# 55                Pokemon Platinum Version Cartridge   Cartridge
# 3                        Sonic the Hedgehog 3 Box Art     Box Art
# 5          Arnold Palmer's Tournament Golf Cartridge   Cartridge
# 31                       Super Mario Sunshine Box Art     Box Art
#
#              format           platform  \
# 46  application/pdf  Nintendo GameCube
# 21       image/jpeg     Sega Dreamcast
# 0   application/pdf      Sega Genesis
# 24  application/pdf     Sega Dreamcast
# 56       image/jpeg       Nintendo DS
# 50  application/pdf       Nintendo DS
# 55       image/jpeg       Nintendo DS
# 3   application/pdf      Sega Genesis
# 5   application/pdf      Sega Genesis
# 31  application/pdf  Nintendo GameCube
#
#                                    publisher  \
# 46                                 Nintendo
# 21                                      Sega
# 0                                       Sega
# 24                                      Sega
# 56     Chunsoft;The Pokemon Company;Nintendo
# 50                                 Nintendo
# 55  Nintendo;Game Freak;The Pokemon Company
# 3                                       Sega
# 5                                       Sega
# 31                                 Nintendo
#
#                                         gameid  \
# 46      The Legend of Zelda Twilight Princess
# 21                        Sega Marine Fishing
# 0             Arnold Palmer's Tournament Golf
# 24                            Sonic Adventure
# 56  Pokemon Mystery Dungeon: Explorers of Sky
# 50                 Animal Crossing Wild World
# 55                   Pokemon Platinum Version
# 3                         Sonic the Hedgehog 3
# 5             Arnold Palmer's Tournament Golf
# 31                       Super Mario Sunshine
#
#                                               creator  date       objectid  \
# 46                                Nintendo of America  2006  gctloztpm.pdf
# 21                                   Sega of America   2000     dcsmfd.jpg
# 0                                     Sega of America  1989    sgaptgb.pdf
# 24  Monika Hudgins;Chieko Nakamura;Makoto Nishino;...  1999      dcsam.pdf
# 56            The Pokemon Company;Nintendo of America  2009  dspmdeosc.jpg
# 50                                Nintendo of America  2005    dsacwwb.pdf
# 55            The Pokemon Company;Nintendo of America  2009     dsppvc.jpg
# 3                         Sega of America;Greg Martin  1994    sgsth3b.pdf
# 5                                   Sega Enterprises   1989    sgaptgc.pdf
# 31                                Nintendo of America  2002     gcsmsb.pdf
#
#          filename language                                        description  \
# 46  GcTLOZTPm.pdf  English  This is the instruction manual for The Legend ...
# 21     DcSMFd.jpg  English  This is the optical storage disc for Sega Mari...
# 0     SgAPTGb.pdf  English  This is the packaging and accompanying box art...
# 24      DcSAm.pdf  English  This is the instruction manual for Sonic Adven...
# 56  DsPMDEOSc.jpg  English  This is the physical storage cartridge for Pok...
# 50    DsACWWb.pdf  English  This is the packaging and accompanying box art...
# 55     DsPPVc.jpg  English  This is the physical storage cartridge for Pok...
# 3     SgSTH3b.pdf  English  This is the packaging and accompanying box art...
# 5     SgAPTGc.pdf  English  This is the physical storage cartridge for Arn...
# 31     GcSMSb.pdf  English  This is the packaging and accompanying box art...
#
#                             franchise                    genre  \
# 46               The Legend of Zelda           ActionAdventure
# 21                      Sega Fishing                    Sports
# 0                                 N/A                   Sports
# 24                Sonic the Hedgehog           Platform;Action
# 56  Pokemon; Pokemon Mystery Dungeon   Japanese RPG;Rogue-Like
# 50                   Animal Crossing          Social Simulator
# 55                           Pokemon              Japanese RPG
# 3                 Sonic the Hedgehog           Platform;Action
# 5                                 N/A                   Sports
# 31                  Super Mario Bros           Platform;Action
#
#                                                rights  \
# 46  Material protected under copyright; Using unde...
# 21  Material protected under copyright; Using unde...
# 0   Material protected under copyright; Using unde...
# 24  Material protected under copyright; Using unde...
# 56  Material protected under copyright; Using unde...
# 50  Material protected under copyright; Using unde...
# 55  Material protected under copyright; Using unde...
# 3   Material protected under copyright; Using unde...
# 5   Material protected under copyright; Using unde...
# 31  Material protected under copyright; Using unde...
#
#                                          youtube-link  \
# 46        https://www.youtube.com/watch?v=wPin8YYV5-c
# 21        https://www.youtube.com/watch?v=VcxBIWb3a1g
# 0         https://www.youtube.com/watch?v=FkVJ7ES_y30
# 24        https://www.youtube.com/watch?v=A2wzZt9SVuA
# 56        https://www.youtube.com/watch?v=32rPL935tgI
# 50        https://www.youtube.com/watch?v=rhn4kNkrX48
# 55        https://www.youtube.com/watch?v=w5VyM7S56GU
# 3         https://www.youtube.com/watch?v=Q260BqrWHgo
# 5         https://www.youtube.com/watch?v=FkVJ7ES_y30
# 31  https://www.youtube.com/watch?v=KhlUjmsytTE&li...
#
#                                   internetarchivelink  \
# 46                                                NaN
# 21                                                NaN
# 0   https://archive.org/details/Arnold_Palmer_Tour...
# 24                                                NaN
# 56                                                NaN
# 50                                                NaN
# 55                                                NaN
# 3               https://archive.org/details/sonic_bin
# 5   https://archive.org/details/Arnold_Palmer_Tour...
# 31                                                NaN
#
#                                         reference_url
# 46  https://johaknigiu.github.io/Digital-Videogame...
# 21  https://johaknigiu.github.io/Digital-Videogame...
# 0   https://johaknigiu.github.io/Digital-Videogame...
# 24  https://johaknigiu.github.io/Digital-Videogame...
# 56  https://johaknigiu.github.io/Digital-Videogame...
# 50  https://johaknigiu.github.io/Digital-Videogame...
# 55  https://johaknigiu.github.io/Digital-Videogame...
# 3   https://johaknigiu.github.io/Digital-Videogame...
# 5   https://johaknigiu.github.io/Digital-Videogame...
# 31  https://johaknigiu.github.io/Digital-Videogame...

# %% [markdown]
# **H6** This is for bonus!
# Try to write a pandas statement that will display your answer from **H4**. There are plenty of ways to do this, so feel free to use your imagination. What I have started for you here might not work, so feel free to change it as needed.

# %%
cb_normalized["gameid"].value_counts()
# Out:
# gameid
# Animal Crossing                               4
# Sonic the Hedgehog 3                          3
# Caesar's Palace                               3
# Sonic CD                                      3
# Sonic the Hedgehog                            3
# Super Mario Sunshine                          3
# Sonic Adventure                               3
# Sega Marine Fishing                           3
# Sega Sports World Series Baseball 2K2         3
# Phantasy Star Online Ver. 2                   3
# Super Smash Bros. Melee                       3
# Star Wars Rogue Leader Rogue Squadron II      3
# Sonic Adventure 2                             3
# Pokemon Platinum Version                      3
# FZero GX                                      3
# The Legend of Zelda Twilight Princess         3
# Mario Kart DS                                 3
# Pokemon Mystery Dungeon: Explorers of Sky     3
# Animal Crossing Wild World                    3
# Arnold Palmer's Tournament Golf               2
# System                                        1
# Name: count, dtype: int64

# %% [markdown]
# ## All Done!
#
# Congrats you are finished with this week's work. First save as PDF so that you can upload to the Course site then click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work.
